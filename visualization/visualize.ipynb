# %%
import os
ROOT_PATH = "/home/atlask/Desktop/Face_Scanning_in_Prosopagnosia"

import sys
sys.path.append(ROOT_PATH)

import warnings
warnings.filterwarnings('ignore')

from visualization.utils import *
from tools.loading import *
# Out:
# 2023-06-21 17:55:25.899554: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-21 17:55:25.903483: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-21 17:55:25.979073: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-21 17:55:25.980014: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
positive_class = 'dp'
num_fixations = 16
labels= {'positive_class':positive_class,'negative_class':'control'}
SPLITS_PATH = os.path.join(ROOT_PATH,'image_classification','splits',labels['positive_class'])

model_name = 'scanpath'

positive_trials, negative_trials = trials_by_probability(splits_path= SPLITS_PATH,
                                                        positive_class= positive_class,
                                                       path=ROOT_PATH, 
                                                       labels=labels,
                                                       num_fixations=num_fixations,
                                                       model_name=model_name,
                                                       return_arrays = True, 
                                                       probability=0.1)

# %%
plot_face(images = positive_trials, factor = 1/4, fig_path= 'scanpath_most_dp_like')

# %%
plot_face(negative_trials, factor = 1/4, fig_path= 'scanpath_most_control_like')

# %%
model_name = 'temporal'
SPLITS_PATH = os.path.join(ROOT_PATH,'image_classification','splits',labels['positive_class'])

positive_trials, negative_trials = trials_by_probability(splits_path=SPLITS_PATH,
                                                         positive_class= positive_class,
                                                       path=ROOT_PATH, 
                                                       labels=labels,
                                                       num_fixations=num_fixations,
                                                       model_name=model_name,
                                                       return_arrays = True, 
                                                       probability=0.1)

# %%
plot_roi(positive_trials, 16, fig_path= 'temporal_most_dp_like')

# %%
plot_roi(negative_trials, 16, 'temporal_most_control_like')
