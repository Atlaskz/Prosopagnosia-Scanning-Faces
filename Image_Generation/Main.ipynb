# %%
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/Colab Notebooks/Project 0/Project 0/Notebooks"
import sys
sys.path.append(path)
import os
from Analysis.Image_Generation.ImageGen import *
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
groups = {'AP':4,'DP':16}
data_path = os.path.join(path,'Data') # path where the eyetracking data is 
image_path = os.path.join(path,'Test_Images') #path were images are to be saved
phases = ['Learning','Target','Distractor']


for key, val in groups.items():
    ScanpathImages(data_path=data_path,image_path=image_path,num_fixations=val,
                    labels={'Positive_Class':f'{key} - New ROI Data','Negative_Class':'Control - New ROI Data'},
                    phases=phases)
    
    TemporalImages(data_path=data_path,image_path=image_path,num_fixations=val,
                    labels={'Positive_Class':f'{key} - New ROI Data','Negative_Class':'Control - New ROI Data'},
                    phases=phases)
