# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/Colab Notebooks/Project 0/Project 0/Notebooks"
import sys
sys.path.append(path)
import os
import matplotlib.pyplot as plt

from Analysis.Image_Classification.Classification import *
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
results_path = os.path.join(path, 'Analysis/Image_Classification')
positive_class = {'AP':4,'DP':16}

for pc, num_fixations in positive_class.items():

  auc_dist = []
  r = 100
  for i in range(r):
    print('\033[1m' + f'Step {i+1} out of {r}:' + '\033[0m')
    image_path = os.path.join(path,'Test_Images')
    image_folder = f'Scanpath Images - {pc} - {num_fixations}'
    hybrid_auc = RandomHybridModel(path=image_path,image_folder=image_folder,positive_class=pc,num_fixations=num_fixations,patience=10)
    auc_dict.append(hybrid_auc)
    pd.DataFrame.from_dict({'auc':auc_dist}).to_csv(os.path.join(results_path,'random_AUC_',pc,'.csv' ,index=False))

  x = [list(pd.read_csv(os.path.join(results_path,'random_AUC_',pc,'.csv').auc.astype(float)))]

  # the histogram of the data
  n, bins, patches = plt.hist(x, 5, density=True, facecolor='blue', alpha=0.75)

  plt.xlabel('AUC Score')
  plt.ylabel('Probability Density')
  plt.text(0.74, 6, 'Actual AUC')
  #plt.xlim(40, 160)
  #plt.ylim(0, 0.03)
  plt.axvline(x=0.8, color='red', linestyle='--')
  plt.show()
  plt.savefig(os.path.join(results_path,'random_AUC_plot_',pc))
# Out:
# Step 1 out of 100:
# Epoch 1/30
# ...
# 1/1 [==============================] - 16s 16s/step - loss: 1.2844 - accuracy: 0.1875
# Epoch 2/30
# ...
# 1/1 [==============================] - 0s 101ms/step - loss: 1.5362 - accuracy: 0.0000e+00
# Epoch 3/30
# ...
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0574 - accuracy: 0.2188
# Epoch 4/30
# ...
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8470 - accuracy: 0.4286
# Epoch 5/30
# ...
# 1/1 [==============================] - 0s 36ms/step - loss: 0.9393 - accuracy: 0.2812
# Epoch 6/30
# ...
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6560 - accuracy: 0.4286
# Epoch 7/30
# ...
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8781 - accuracy: 0.4688
# Epoch 8/30
# ...
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9620 - accuracy: 0.1429
# Epoch 9/30
# ...
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6790 - accuracy: 0.5938
# Epoch 10/30
# ...
