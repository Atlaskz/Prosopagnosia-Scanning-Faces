# %%
from google.colab import drive
drive.mount('/content/drive')

root_path = "/content/drive/MyDrive/Colab Notebooks/Prosopagnosia_Test"
import sys
sys.path.append(root_path)
import os
from analysis.image_generation.imagegen_tools import *
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
num_fixations = 4

data_path = os.path.join(root_path,'data') # path where the eyetracking data is 
image_path = os.path.join(root_path,'images') #path were images are to be saved

labels = {'positive_class':'ap',
          'negative_class':'control'}

# %%
ScanpathImages(data_path=data_path,
               image_path=image_path,
               num_fixations=num_fixations,
               labels=labels)

# %%
TemporalImages(data_path=data_path,
               image_path=image_path,
               num_fixations=num_fixations,
               labels=labels)
