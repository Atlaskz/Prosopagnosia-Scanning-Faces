# %%
from google.colab import drive
drive.mount('/content/drive')

from keras.preprocessing.image import array_to_img
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

path = "/content/drive/MyDrive/Colab Notebooks/Prosopagnosia_Test"
import sys
import os
sys.path.append(path)


from analysis.visualization.visualization_tools import *
from analysis.analysis_tools.loading import *
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
num_fixations = 4
positive_class = 'AP'
labels = {f'positive_class':f'{positive_class} - New ROI Data',
          'negative_class':'Controls - New ROI Data'}


model_name = 'scanpath'

positive_trials, negative_trials = TrialsByProbability(positive_class= positive_class,
                                                       path=path, 
                                                       labels=labels,
                                                       num_fixations=num_fixations,
                                                       model_name=model_name,
                                                       return_arrays = True, 
                                                       probability=0.1)

PlotFace(positive_trials)
