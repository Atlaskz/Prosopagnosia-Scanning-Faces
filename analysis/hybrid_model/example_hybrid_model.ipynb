# %%
from google.colab import drive
drive.mount('/content/drive')
from tensorflow.keras.utils import array_to_img
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

path = "/content/drive/MyDrive/Colab Notebooks/Prosopagnosia_Test"
import sys
import os
sys.path.append(path)
from analysis.hybrid_model.hybrid_classification_tools import HybridModel
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
num_fixations = 4
positive_class = 'ap'

labels = {'positive_class':'ap',
          'negative_class':'control'}

hybrid_results = HybridModel(path,labels,num_fixations,model_weights='manual_random')
# Out:
# 8
