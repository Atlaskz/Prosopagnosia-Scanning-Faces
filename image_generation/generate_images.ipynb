# %%
import os
ROOT_PATH = "/home/atlask/Desktop/Face_Scanning_in_Prosopagnosia"
DATA_PATH = os.path.join(ROOT_PATH,'data')
IMAGE_PATH = os.path.join(ROOT_PATH,'images_curated')

import sys
sys.path.append(ROOT_PATH)

import warnings
warnings.filterwarnings('ignore')

from image_generation.utils import *

# %% [markdown]
# ## APs vs Controls

# %%
num_fixations = 4
labels = {'positive_class':'ap','negative_class':'control'}

make_scanpath_images(data_path=DATA_PATH,
               image_path=IMAGE_PATH,
               num_fixations=num_fixations,
               labels=labels)


make_temporal_images(data_path=DATA_PATH,
               image_path=IMAGE_PATH,
               num_fixations=num_fixations,
               labels=labels)

# %% [markdown]
# ## DPs vs Controls

# %%
num_fixations = 14
labels = {'positive_class':'dp','negative_class':'control'}

make_scanpath_images(data_path=DATA_PATH,
               image_path=IMAGE_PATH,
               num_fixations=num_fixations,
               labels=labels)


make_temporal_images(data_path=DATA_PATH,
               image_path=IMAGE_PATH,
               num_fixations=num_fixations,
               labels=labels)
