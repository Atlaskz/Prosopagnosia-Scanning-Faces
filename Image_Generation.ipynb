# %%
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/Colab Notebooks/Project 0/Project 0/Notebooks"
import sys
sys.path.append(path)
from funcs import *
# Out:
# Mounted at /content/drive

# %%
group = ['AP','DP']

number_of_fixations = [4,16]

for i in range(len(group)):
    scanpath_image_gen(group[i],number_of_fixations[i],path)
    sequence_image_gen(group[i],number_of_fixations[i],path)

# %%
from PIL import Image
img = Image.open("/content/drive/MyDrive/Colab Notebooks/Project 0/Project 0/Notebooks/Scanpath Images - AP/wlcont/Trial_ 40.png")
img.size
# Out:
# (360, 360)

# %%
from PIL import Image
img = Image.open("/content/drive/MyDrive/Colab Notebooks/Project 0/Project 0/Notebooks/Temporal Images - AP/wlcont/Trial: 40.png")
img.size
# Out:
# (279, 271)
